# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
well_data=pd.read_csv("/content/log.csv")
well_data
# Out:
#        Depth     RxoRt      RLL3        SP  ...    RHOC     DPOR     CNLS       GR
# 0      195.0  226.0848    0.4076   69.8953  ... -0.6303  59.2216  30.0657  60.4576
# 1      195.5  223.5031    0.4063   69.2303  ... -0.6409  60.2877  26.7625  54.1495
# 2      196.0  221.4560    0.4047   68.4478  ... -0.6539  61.4914  27.6017  51.9944
# 3      196.5  219.8248    0.4033   67.4843  ... -0.6649  62.3711  31.5870  52.9645
# 4      197.0  218.1438    0.4023   66.3013  ... -0.6705  62.6343  35.8251  54.9659
# ...      ...       ...       ...       ...  ...     ...      ...      ...      ...
# 8734  4806.0    1.1354  398.8031 -125.7813  ...  0.2965   9.2449   0.0675  25.8831
# 8735  4806.5    1.5895  487.2287 -126.0632  ...  0.2977   9.3399   0.0704   9.4402
# 8736  4807.0    4.1163  464.9174 -126.3459  ...  0.2988   9.3589   0.1168   1.7368
# 8737  4807.5    8.4264  353.6349 -126.6086  ...  0.2999   9.2228   0.3403   0.1520
# ...

# %%
list_column = ["RHOB", "SP","RILD", "DPOR","GR"]
color = [ "green", "red", "blue","purple","black"]
plt.figure(figsize=(11,7))
for i in range(len(list_column)):
  plt.subplot(1,5,i+1)
  # Give exception for RDEP for semilog plot
  if list_column[i]=="RDEP":
    plt.semilogx(well_data[list_column[i]], well_data["Depth"], color=color[i])
  else:
    # Others are normal plot
    plt.plot(well_data[list_column[i]], well_data["Depth"], color=color[i])
  
  plt.ylim(3500,1500)
  plt.title(list_column[i])
  plt.grid()

plt.tight_layout(1.5)
plt.savefig('well_log plot.png')
plt.show()
